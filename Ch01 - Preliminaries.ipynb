# %% [markdown]
# # Preliminaries

# %% [markdown]
# ## Book Details
# -----------------------------------------------------------------
# Name : **Python for Data Analysis, 3E**

# %% [markdown]
# Title :	* Python for Data Analysis: Data Wrangling with pandas, NumPy, and Jupyter *
#
# Author :	Wes McKinney
#
# Edition	: 3
#
# Publisher :	"O'Reilly Media, Inc.", 2022
#
# ISBN :	109810398X, 9781098103989
#
# Length :	582 pages

# %% [markdown]
# ---------

# %% [markdown]
# Context : I am learning this book as part of learning Data Science Course from MIT.

# %% [markdown]
# ## Introduction

# %% [markdown]
# Python is an interpreted lanugage. Started in 1991.
# Python has grown to become major interpreted language for Data science and Data handling.

# %% [markdown]
# ------

# %% [markdown]
# ### Python is not good

# %% [markdown]
# Python is not good if
# 1. Computational efficiency or CPU time is more important than development time.
# 2. Building highly concurrent, multithreaded applications, particularly applications with many CPU-bound threads.

# %% [markdown]
# ### Essential Python Libraries

# %% [markdown]
# ##### NumPy
# NumPy, short for Numerical Python, has long been a cornerstone of numerical computing in Python. It provides the data structures, algorithms, and library glue needed for most scientific applications involving numerical data in Python. NumPy contains, among other things:

# %% [markdown]
# ##### pandas
# Pandas provides high-level data structures and functions designed to make working with structured or tabular data intuitive and flexible.

# %% [markdown]
# ##### matplotlib
# matplotlib is the most popular Python library for producing plots and other two-dimensional data visualizations.

# %% [markdown]
# ##### ipython/Jupyter
# IPython is designed for both interactive computing and software development work. It encourages an execute-explore workflow instead of the typical edit-compile-run workflow of many other programming languages.

# %% [markdown]
# ##### SciPy
# Collection of packages addressing a number of foundational problems in scientific computing.

# %% [markdown]
# ##### scikit-learn
# Since the project's inception in 2007, scikit-learn has become the premier general-purpose machine learning toolkit for Python programmers

# %% [markdown]
# ##### statsmodels
# Statsmodels is a statistical analysis package that was seeded by work from Stanford University statistics professor Jonathan Taylor, who implemented a number of regression analysis models popular in the R programming language.

# %% [markdown]
# ### Import Conventions
# The Python community has adopted a number of naming conventions for commonly used modules:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statsmodels as sm

# %%
a=10
print("a is :",a)
b=1
print("a is :",a)
print("b is :",b)
b = -99
print("a is :",a)
print("b is :",b)
# Out:
# a is : 10
# a is : 10
# b is : 1
# a is : 10
# b is : -99

# %%
"
